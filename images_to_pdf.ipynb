# %%
# %pip install fpdf
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40758 sha256=b58d38badce16dd1cb402cc1ad8dd4184f6d091c595a2fb6ae5d23d83773dc9c
#   Stored in directory: /Users/latifahakimana/Library/Caches/pip/wheels/aa/da/11/a3189f34ddc13c26a2d0f329eac46b728c7f31c39e4dc26243
# Successfully built fpdf
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fpdf import FPDF
pdf = FPDF()
imagelist = ['image1.png', 'image2.png']
for image in imagelist:
    pdf.add_page()
    pdf.image(image)
pdf.output("images.pdf", "f")
print("Done")
# Out:
# Done
